# %%
## Data for Business Analytics:

# data - we cannot understand, it is a raw form => once cleaned
# information - start to understand what this is..?
# knowledge - mostly played? after processed

# %%
# rows + columns, what looks like dataframe is called data
# call this data

# %%
# Data vs Database

# Tables + Relationships + Metadata => Database
# Database (start from tables)

# %%
# labels of rows: index
# rows (observations) - index
# variables, attributes - columns

# %% [markdown]
# ## 0. Data

# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
house = pd.read_excel("http://byungwan.com/class/House_Prices.xls")

# %%
house.head()
# Out:
#    HomeID   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East

# %%
house.shape
# Out:
# (128, 8)

# %% [markdown]
# ### Types of data
# rows - observation unit (day, year .. )
# if obs unit is day, month, time : it is called time series data
#
# - cross sectional data (anything but time)
# - time series data
# - panel data

# %% [markdown]
# ### Types of variables
# - Categorical (data placed in categories)
#   - Nominal(no qunatitative relationship) / Ordinal(data ranked)
# - Numerical
#   - Discrete / Continuous
# - Textual

# %% [markdown]
# Gender : Categorical (nominal) /
# Age : Numerical (interval) /
# C.Class : Categorical (Ordinal) /
# Discount : Categorical (nominal) /
# Visit/Purchase : Numerical (Count) /
# Email/SNS : Categorical(Nominal) /
# Sales: Numerical

# %% [markdown]
# ### Dummies
# Categorical to numerical
