# %% [markdown]
# ## Intro to Python
# After the # sign, it becomes a title

# %% [markdown]
# ### 1. Importing images and videos
# After ##, it becomes a subtitle

# %% [markdown]
# Note (it becomes a paragraph)

# %%
# press the box & a -> make a new box above
# press the box & b -> make a new box below
# press the box & x -> delete the box

# %%
# http://byungwan.com/class/goodjob.jpg
# bring the image to the jupyter notebook
# look up for python library : image

# %%
from IPython.display import Image
# Capital letters should be distinguished
# IPython provide the library

# %%
Image(url = "http://byungwan.com/class/goodjob.jpg")
# Trying to bring the image to this notebook
# Go to this address and put it in here
# Out:
# <img src="http://byungwan.com/class/goodjob.jpg"/>

# %%
Image(url = "http://byungwan.com/class/goodjob.jpg", width=100)
# size
# Out:
# <img src="http://byungwan.com/class/goodjob.jpg" width="100"/>

# %%
# if there is number -> it is working
# if there is no number -> it did not run yet

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("K5KVEU3aaeQ")
#https://www.youtube.com/watch?v=K5KVEU3aaeQ
# after the = sign is the what you need to put in

# %%
YouTubeVideo("K5KVEU3aaeQ", width = 100, height = 100)
# The video does not change the height proportionally

# %% [markdown]
# ### 2. Operator

# %%
1+2
# Out:
# 3

# %%
3*9
# Out:
# 27

# %%
16/2
# Out:
# 8.0

# %%
a = 1
b = 2

# %%
a+b
# Out:
# 3

# %%
c = "Korea University"
d = "Business School"

# %%
c + d
# Out:
# 'Korea UniversityBusiness School'

# %%
# addition of text -> only in python

# %%
c + ' ' + d
# the output is text
# Out:
# 'Korea University Business School'

# %% [markdown]
# ### 3. Data Type

# %%
a
# Out:
# 1

# %%
type(a)
# Out:
# int

# %%
e = '1'

# %%
e
# Out:
# '1'

# %%
type(e)
# Out:
# str

# %%
# add text together by + sign

# %%
a+1
# Out:
# 2

# %%
a+e
# a is number, e is text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 a+e
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
e + "1"
# text 1 + text 1 = text 11
# Out:
# '11'

# %%
f = 4/7
f
# Out:
# 0.5714285714285714

# %%
type(f)
# Out:
# float

# %%
g = str(f)
# if you put str(f) -> convert f to string
g
# Out:
# '0.5714285714285714'

# %%
type(g)
# Out:
# str

# %%
g = int(f)
g
# this is different from rounding
# Out:
# 0

# %%
round(f)
# Out:
# 1

# %% [markdown]
# ### 4. Logic

# %%
a == 1
# Out:
# True

# %%
a == "1"
# Out:
# False

# %%
e == "1"
# Out:
# True

# %%
a != 2
# != is not equal to
# Out:
# True

# %%
a != 1
# Out:
# False

# %%
a != '1'
# Out:
# True

# %%
a > 3
# Out:
# False

# %%
a<3
# Out:
# True

# %%
age = 10

# %%
if age>18:
    print("Beer")
elif age>10:
    print("Coke")
else:
    print("Milk")
# Out:
# Milk

# %% [markdown]
# ## 5. Array (List / Vector)

# %%
BTS = ['Jungkook', 'V', 'Jimin', 'RM', 'Suga', 'J-Hope', 'Jin']
# 7 elements

# %%
BTS[1]
# numbering starts with 0 / number of second -> 1
# Out:
# 'V'

# %%
BTS[0:2]
# Out:
# ['Jungkook', 'V']

# %%
BTS[0:3]
# Out:
# ['Jungkook', 'V', 'Jimin']

# %%
BTS[1:3]
# Out:
# ['V', 'Jimin']

# %%
[BTS[0], BTS[2]]
# Out:
# ['Jungkook', 'Jimin']

# %%
list(range(0,4))
# Out:
# [0, 1, 2, 3]

# %%
list(range(0,2))
# Out:
# [0, 1]

# %% [markdown]
# ## 6. DataFrame (Table)

# %%
from random import randint

# %%
randint(0, 100)
# Out:
# 38

# %%
import numpy as np

# %%
np.random.randint(0, 100, size=4)
# np will create an array
# Out:
# array([40,  8, 26, 31])

# %%
np.random.randint(0, 100, size=(7,4))
# Out:
# array([[48, 17,  2,  6],
#        [81, 87, 48, 37],
#        [81, 83, 74, 57],
#        [22, 83, 11, 62],
#        [92,  9,  1, 74],
#        [55, 75, 85, 19],
#        [10, 27, 41, 76]])

# %%
values = np.random.randint(0,100, size=(7,4))

# %%
values
# Out:
# array([[74, 60, 50, 35],
#        [69, 62,  2, 79],
#        [28, 83, 43, 17],
#        [74, 80, 54, 12],
#        [94, 20, 52, 45],
#        [90, 36, 25, 13],
#        [40, 58, 37, 77]])

# %%
import pandas as pd

# %%
pd.DataFrame(values)
# Out:
#     0   1   2   3
# 0  74  60  50  35
# 1  69  62   2  79
# 2  28  83  43  17
# 3  74  80  54  12
# 4  94  20  52  45
# 5  90  36  25  13
# 6  40  58  37  77

# %%
table = pd.DataFrame(values)

# %%
table
# Out:
#     0   1   2   3
# 0  74  60  50  35
# 1  69  62   2  79
# 2  28  83  43  17
# 3  74  80  54  12
# 4  94  20  52  45
# 5  90  36  25  13
# 6  40  58  37  77

# %%
firms = ["F1", "F2", "F3", "F4"]

# %%
table.columns = firms
table
# Out:
#    F1  F2  F3  F4
# 0  74  60  50  35
# 1  69  62   2  79
# 2  28  83  43  17
# 3  74  80  54  12
# 4  94  20  52  45
# 5  90  36  25  13
# 6  40  58  37  77

# %%
dates = ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']

# %%
table.index = dates
table
# Out:
#       F1  F2  F3  F4
# Mon   74  60  50  35
# Tue   69  62   2  79
# Wed   28  83  43  17
# Thur  74  80  54  12
# Fri   94  20  52  45
# Sat   90  36  25  13
# Sun   40  58  37  77

# %% [markdown]
# ## 7. Function

# %%
def add(a,b,c,d):
    return (a+b+c+d)

# %%
add(1,2,3,4)
# Out:
# 10

# %%
add("K","U","B","S")
# Out:
# 'KUBS'
